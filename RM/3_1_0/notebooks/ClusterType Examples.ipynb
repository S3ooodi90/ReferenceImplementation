# %% [markdown]
# # Examples using the ClusterType

# %% [markdown]
# **Set the path to the folder containing the library files and import the extended datatypes.**

# %%
import sys 
sys.path.append("../pylib/")
from s3m_struct import ClusterType, XdAdapterType
from s3m_xdt import XdStringType, XdTemporalType, XdOrdinalType, XdCountType

# %% [markdown]
# Review the documentation of ClusterType. Note the class signature requires a *label* (string name)

# %%
help(ClusterType)
# Out:
# Help on class ClusterType in module s3m_struct:
#
# class ClusterType(ItemType)
#  |  ClusterType(label)
#  |
#  |  The grouping component, which may contain further instances of itself or
#  |  any eXtended datatype, in an ordered list.
#  |
#  |  This component serves as the root component for arbitrarily complex
#  |  structures.
#  |
#  |  Method resolution order:
#  |      ClusterType
#  |      ItemType
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, label)
#  |      The semantic label (name of the model) is required.
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  asXSD(self)
#  |      Return a XML Schema stub for the Cluster.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  items
#  |      The items contained in a Cluster.
#  |
#  |  label
#  |      The semantic name of the ClusterType.
#  |
#  |  mcuid
#  |      The unique identifier of the component.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ItemType:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# Create a Cluster instance and provide a *label*. A Cluster is the building block of data models. It allows the modeler to logical group XdTypes. Clusters can themselves contain Clusters to an infinite level. However, practical models will seldom have more than 2 or 3 levels of nesting. A XdAnyType subtype must be wrapped in an adapter (XdAdapterType) to be included in a ClusterType.
#
# For this example we will create a model for this data entry form.
#
#
# <div class="logo-container">
#   <div class="logo"><img src="images/Data-Entry-Form.png" height="400" width="400"/></div>
# </div>

# %%
ERF = ClusterType('Employee Record Form')
print(ERF)
# Out:
# ClusterType : Employee Record Form, ID: cjn61xv6f0000lw8pbj3ye1w9

# %%
# Use a XdStringType to capture the action
choice = []
choice.append(('Add New','https://datainsights.tech/examples/AddNewRecord'))
choice.append(('Modify','https://datainsights.tech/examples/ModifyRecord'))
choice.append(('Delete','https://datainsights.tech/examples/DeleteRecord'))
action = XdStringType("Record Action")
action.docs = "Select the action to perform."
action.enums = choice
print(action)
# Out:
# XdStringType : Record Action, ID: cjn61yemy0001lw8pkzxgrrvh

# %% [markdown]
# Use a regular expression to limit the Employee Number to one character of A,B,C,D or E and 5 digits.
#
# Examples: A09098, D76547, etc.

# %%
empnum = XdStringType('Employee Number')
empnum.docs = 'An employee number consists of a single character department code (A-E) and 5 digits (0-9).'
empnum.definition_url = 'https://datainsights.tech/examples/EmployeeNumber'
empnum.regex = '[A-E]{1}[0-9]{5}'
print(empnum)
# Out:
# XdStringType : Employee Number, ID: cjn61zt840003lw8p712beeb2

# %%
joined = XdTemporalType("Date of Joining")
joined.docs = "Require a full date. Disallow all others."
joined.cardinality = ('date', (1,1))
joined.cardinality = ('time', (0,0))
joined.cardinality = ('datetime', (0,0))
joined.cardinality = ('day', (0,0))
joined.cardinality = ('month', (0,0))
joined.cardinality = ('year', (0,0))
joined.cardinality = ('year_month', (0,0))
joined.cardinality = ('month_day', (0,0))
joined.cardinality = ('duration', (0,0))
print(joined)
# Out:
# XdTemporalType : Date of Joining, ID: cjn620urt0005lw8phnccc99t

# %%
fname = XdStringType('First Name')
fname.docs = "The employee's first name."
fname.definition_url = 'https://datainsights.tech/examples/EmployeeFirstName'
fname.cardinality = ('value', (1,1))
print(fname)
# Out:
# XdStringType : First Name, ID: cjn6211my0007lw8pcman5izl

# %%
lname = XdStringType('Last Name')
lname.docs = "The employee's last name."
lname.definition_url = 'https://datainsights.tech/examples/EmployeeLastName'
lname.cardinality = ('value', (1,1))
print(lname)
# Out:
# XdStringType : Last Name, ID: cjn621bc80009lw8pkayf36ji

# %%
desig = XdStringType('Designation')
desig.docs = "The employee's designation."
desig.definition_url = 'https://datainsights.tech/examples/EmployeeDesignation'
jobs = []
jobs.append(('Manager', 'https://datainsights.tech/examples/EmployeeDesignation#Manager'))
jobs.append(('Foreman', 'https://datainsights.tech/examples/EmployeeDesignation#Forman'))
jobs.append(('LineWorker', 'https://datainsights.tech/examples/EmployeeDesignation#LineWorker'))
desig.enums = jobs
print(desig)
# Out:
# XdStringType : Designation, ID: cjn621rb6000blw8pkb9y60eu

# %%
dob = XdTemporalType("Date of Birth")
dob.docs = "DOB allows a full date or just a month/year."
dob.cardinality = ('date', (0,1))
dob.cardinality = ('time', (0,0))
dob.cardinality = ('datetime', (0,0))
dob.cardinality = ('day', (0,0))
dob.cardinality = ('month', (0,0))
dob.cardinality = ('year', (0,0))
dob.cardinality = ('year_month', (0,1))
dob.cardinality = ('month_day', (0,0))
dob.cardinality = ('duration', (0,0))
print(dob)
# Out:
# XdTemporalType : Date of Birth, ID: cjn622ak0000dlw8pui7in61y

# %%
qual = XdStringType('Highest Qualification')
qual.docs = "The employee's highest level of qualification."
qual.definition_url = 'https://datainsights.tech/examples/EmployeeQualification'
level = []
level.append(('Level1', 'https://datainsights.tech/examples/EmployeeQualification#Level1'))
level.append(('Level2', 'https://datainsights.tech/examples/EmployeeQualification#Level2'))
level.append(('Level3', 'https://datainsights.tech/examples/EmployeeQualification#Level3'))
qual.enums = level
print(qual)
# Out:
# XdStringType : Highest Qualification, ID: cjn622f0j000flw8pydlxwru0

# %%
# create the units model
unit = XdStringType('Years')
unit.docs = "Count of the years of experience."
unit.definition_url = 'https://datainsights.tech/examples/Experience'

# now the count model
exp = XdCountType("Years of Experience")
exp.docs = "Record the number of years of experience of the employee."
exp.definition_url = 'https://datainsights.tech/examples/Experience#Years'
exp.min_inclusive = 0
exp.max_inclusive = 99
exp.units = unit
print(exp)
# Out:
# XdCountType : Years of Experience, ID: cjn622weg000jlw8pszv5qhos

# %%
# Each component needs to be placed inside a new adapter before being added to the Cluster
a = XdAdapterType()
a.value = action # form action
# add the adapter to the cluster
ERF.items = a

a = XdAdapterType()
a.value = empnum # Employee Number
ERF.items = a

a = XdAdapterType()
a.value = joined  
ERF.items = a

a = XdAdapterType()
a.value = fname 
ERF.items = a

a = XdAdapterType()
a.value = lname
ERF.items = a

a = XdAdapterType()
a.value = desig
ERF.items = a

a = XdAdapterType()
a.value = dob
ERF.items = a

a = XdAdapterType()
a.value = qual
ERF.items = a

a = XdAdapterType()
a.value = exp
ERF.items = a

print(ERF)
# Out:
# ClusterType : Employee Record Form, ID: cjn61xv6f0000lw8pbj3ye1w9

# %%
print(ERF.asXSD())
# Out:
#
# <xs:element name="ms-cjn61xv6f0000lw8pbj3ye1w9" substitutionGroup="s3m:Items" type="s3m:mc-cjn61xv6f0000lw8pbj3ye1w9"/>
#   <xs:complexType name="mc-cjn61xv6f0000lw8pbj3ye1w9">
#     <xs:complexContent>
#       <xs:restriction base="s3m:ClusterType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Employee Record Form"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn61yemy0002lw8prpb4lq8o"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn61zt840004lw8pmw7bn4u0"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn620urt0006lw8pp4mhtapz"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn6211my0008lw8po8a3kk5r"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn621bc8000alw8pj6f5ifhd"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn621rb6000clw8psmgc2fyh"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn622ak1000elw8pxxgzorf6"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn622f0j000glw8pn1usfse8"/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ms-cjn622weg000klw8pvivpj5ck"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#
# <xs:element name="ms-cjn61yemy0002lw8prpb4lq8o" substitutionGroup="s3m:Items" type="s3m:mc-cjn61yemy0002lw8prpb4lq8o"/>
#   <xs:complexType name="mc-cjn61yemy0002lw8prpb4lq8o">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn61yemy0001lw8pkzxgrrvh"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn61yemy0001lw8pkzxgrrvh" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn61yemy0001lw8pkzxgrrvh"/>
#   <xs:complexType name="mc-cjn61yemy0001lw8pkzxgrrvh">
#     <xs:annotation>
#       <xs:documentation>
#         Select the action to perform.
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn61yemy0001lw8pkzxgrrvh">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource=""/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Record Action"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value' type='xs:string'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value'>
#               <xs:simpleType>
#                 <xs:restriction base='xs:string'>
#                   <xs:enumeration value='Add New'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn61yemy0001lw8pkzxgrrvh/xdstring-value/Add%20New'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn61yemy0001lw8pkzxgrrvh'/>
#                         <rdfs:label>Add New</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/AddNewRecord</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                   <xs:enumeration value='Modify'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn61yemy0001lw8pkzxgrrvh/xdstring-value/Modify'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn61yemy0001lw8pkzxgrrvh'/>
#                         <rdfs:label>Modify</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/ModifyRecord</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                   <xs:enumeration value='Delete'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn61yemy0001lw8pkzxgrrvh/xdstring-value/Delete'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn61yemy0001lw8pkzxgrrvh'/>
#                         <rdfs:label>Delete</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/DeleteRecord</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                 </xs:restriction>
#               </xs:simpleType>
#             </xs:element>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
# <xs:element name="ms-cjn61zt840004lw8pmw7bn4u0" substitutionGroup="s3m:Items" type="s3m:mc-cjn61zt840004lw8pmw7bn4u0"/>
#   <xs:complexType name="mc-cjn61zt840004lw8pmw7bn4u0">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn61zt840003lw8p712beeb2"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn61zt840003lw8p712beeb2" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn61zt840003lw8p712beeb2"/>
#   <xs:complexType name="mc-cjn61zt840003lw8p712beeb2">
#     <xs:annotation>
#       <xs:documentation>
#         An employee number consists of a single character department code (A-E) and 5 digits (0-9).
#         Definition: https%3A//datainsights.tech/examples/EmployeeNumber
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn61zt840003lw8p712beeb2">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/EmployeeNumber"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Employee Number"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value'>
#               <xs:simpleType>
#                 <xs:restriction base='xs:string'>
#                   <xs:pattern value='[A-E]{1}[0-9]{5}'/>
#                 </xs:restriction>
#               </xs:simpleType>
#             </xs:element>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
# <xs:element name="ms-cjn620urt0006lw8pp4mhtapz" substitutionGroup="s3m:Items" type="s3m:mc-cjn620urt0006lw8pp4mhtapz"/>
#   <xs:complexType name="mc-cjn620urt0006lw8pp4mhtapz">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn620urt0005lw8phnccc99t"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn620urt0005lw8phnccc99t" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn620urt0005lw8phnccc99t"/>
#   <xs:complexType name="mc-cjn620urt0005lw8phnccc99t">
#     <xs:annotation>
#       <xs:documentation>
#         Require a full date. Disallow all others.
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn620urt0005lw8phnccc99t">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdTemporalType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource=""/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdTemporalType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Date of Joining"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='1' name='xdtemporal-date' type='xs:date'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-time' type='xs:time'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-datetime' type='xs:dateTime'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-day' type='xs:gDay'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-month' type='xs:gMonth'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-year' type='xs:gYear'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-year-month' type='xs:gYearMonth'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-month-day' type='xs:gMonthDay'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-duration' type='xs:duration'/>
#           </xs:sequence>
#         </xs:restriction>
#       </xs:complexContent>
#     </xs:complexType>
#
#
# <xs:element name="ms-cjn6211my0008lw8po8a3kk5r" substitutionGroup="s3m:Items" type="s3m:mc-cjn6211my0008lw8po8a3kk5r"/>
#   <xs:complexType name="mc-cjn6211my0008lw8po8a3kk5r">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn6211my0007lw8pcman5izl"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn6211my0007lw8pcman5izl" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn6211my0007lw8pcman5izl"/>
#   <xs:complexType name="mc-cjn6211my0007lw8pcman5izl">
#     <xs:annotation>
#       <xs:documentation>
#         The employee's first name.
#         Definition: https%3A//datainsights.tech/examples/EmployeeFirstName
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn6211my0007lw8pcman5izl">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/EmployeeFirstName"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="First Name"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='1' name='xdstring-value' type='xs:string'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
# <xs:element name="ms-cjn621bc8000alw8pj6f5ifhd" substitutionGroup="s3m:Items" type="s3m:mc-cjn621bc8000alw8pj6f5ifhd"/>
#   <xs:complexType name="mc-cjn621bc8000alw8pj6f5ifhd">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn621bc80009lw8pkayf36ji"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn621bc80009lw8pkayf36ji" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn621bc80009lw8pkayf36ji"/>
#   <xs:complexType name="mc-cjn621bc80009lw8pkayf36ji">
#     <xs:annotation>
#       <xs:documentation>
#         The employee's last name.
#         Definition: https%3A//datainsights.tech/examples/EmployeeLastName
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn621bc80009lw8pkayf36ji">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/EmployeeLastName"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Last Name"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='1' name='xdstring-value' type='xs:string'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
# <xs:element name="ms-cjn621rb6000clw8psmgc2fyh" substitutionGroup="s3m:Items" type="s3m:mc-cjn621rb6000clw8psmgc2fyh"/>
#   <xs:complexType name="mc-cjn621rb6000clw8psmgc2fyh">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn621rb6000blw8pkb9y60eu"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn621rb6000blw8pkb9y60eu" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn621rb6000blw8pkb9y60eu"/>
#   <xs:complexType name="mc-cjn621rb6000blw8pkb9y60eu">
#     <xs:annotation>
#       <xs:documentation>
#         The employee's designation.
#         Definition: https%3A//datainsights.tech/examples/EmployeeDesignation
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn621rb6000blw8pkb9y60eu">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/EmployeeDesignation"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Designation"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value' type='xs:string'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value'>
#               <xs:simpleType>
#                 <xs:restriction base='xs:string'>
#                   <xs:enumeration value='Manager'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn621rb6000blw8pkb9y60eu/xdstring-value/Manager'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn621rb6000blw8pkb9y60eu'/>
#                         <rdfs:label>Manager</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/EmployeeDesignation#Manager</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                   <xs:enumeration value='Foreman'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn621rb6000blw8pkb9y60eu/xdstring-value/Foreman'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn621rb6000blw8pkb9y60eu'/>
#                         <rdfs:label>Foreman</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/EmployeeDesignation#Forman</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                   <xs:enumeration value='LineWorker'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn621rb6000blw8pkb9y60eu/xdstring-value/LineWorker'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn621rb6000blw8pkb9y60eu'/>
#                         <rdfs:label>LineWorker</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/EmployeeDesignation#LineWorker</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                 </xs:restriction>
#               </xs:simpleType>
#             </xs:element>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
# <xs:element name="ms-cjn622ak1000elw8pxxgzorf6" substitutionGroup="s3m:Items" type="s3m:mc-cjn622ak1000elw8pxxgzorf6"/>
#   <xs:complexType name="mc-cjn622ak1000elw8pxxgzorf6">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn622ak0000dlw8pui7in61y"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn622ak0000dlw8pui7in61y" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn622ak0000dlw8pui7in61y"/>
#   <xs:complexType name="mc-cjn622ak0000dlw8pui7in61y">
#     <xs:annotation>
#       <xs:documentation>
#         DOB allows a full date or just a month/year.
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn622ak0000dlw8pui7in61y">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdTemporalType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource=""/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdTemporalType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Date of Birth"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdtemporal-date' type='xs:date'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-time' type='xs:time'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-datetime' type='xs:dateTime'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-day' type='xs:gDay'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-month' type='xs:gMonth'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-year' type='xs:gYear'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdtemporal-year-month' type='xs:gYearMonth'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-month-day' type='xs:gMonthDay'/>
#           <xs:element maxOccurs='0' minOccurs='0' name='xdtemporal-duration' type='xs:duration'/>
#           </xs:sequence>
#         </xs:restriction>
#       </xs:complexContent>
#     </xs:complexType>
#
#
# <xs:element name="ms-cjn622f0j000glw8pn1usfse8" substitutionGroup="s3m:Items" type="s3m:mc-cjn622f0j000glw8pn1usfse8"/>
#   <xs:complexType name="mc-cjn622f0j000glw8pn1usfse8">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn622f0j000flw8pydlxwru0"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn622f0j000flw8pydlxwru0" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn622f0j000flw8pydlxwru0"/>
#   <xs:complexType name="mc-cjn622f0j000flw8pydlxwru0">
#     <xs:annotation>
#       <xs:documentation>
#         The employee's highest level of qualification.
#         Definition: https%3A//datainsights.tech/examples/EmployeeQualification
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn622f0j000flw8pydlxwru0">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/EmployeeQualification"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Highest Qualification"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value' type='xs:string'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value'>
#               <xs:simpleType>
#                 <xs:restriction base='xs:string'>
#                   <xs:enumeration value='Level1'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn622f0j000flw8pydlxwru0/xdstring-value/Level1'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn622f0j000flw8pydlxwru0'/>
#                         <rdfs:label>Level1</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/EmployeeQualification#Level1</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                   <xs:enumeration value='Level2'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn622f0j000flw8pydlxwru0/xdstring-value/Level2'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn622f0j000flw8pydlxwru0'/>
#                         <rdfs:label>Level2</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/EmployeeQualification#Level2</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                   <xs:enumeration value='Level3'>
#                   <xs:annotation>
#                     <xs:appinfo>
#                       <rdfs:Class rdf:about='mc-cjn622f0j000flw8pydlxwru0/xdstring-value/Level3'>
#                         <rdfs:subPropertyOf rdf:resource='mc-cjn622f0j000flw8pydlxwru0'/>
#                         <rdfs:label>Level3</rdfs:label>
#                         <rdfs:isDefinedBy>https://datainsights.tech/examples/EmployeeQualification#Level3</rdfs:isDefinedBy>
#                       </rdfs:Class>
#                     </xs:appinfo>
#                   </xs:annotation>
#                   </xs:enumeration>
#                 </xs:restriction>
#               </xs:simpleType>
#             </xs:element>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
# <xs:element name="ms-cjn622weg000klw8pvivpj5ck" substitutionGroup="s3m:Items" type="s3m:mc-cjn622weg000klw8pvivpj5ck"/>
#   <xs:complexType name="mc-cjn622weg000klw8pvivpj5ck">
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdAdapterType">
#         <xs:sequence>
#           <xs:element maxOccurs="unbounded" minOccurs="0" ref="s3m:ms-cjn622weg000jlw8pszv5qhos"/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
#
#   <xs:element name="ms-cjn622weg000jlw8pszv5qhos" substitutionGroup="s3m:XdAdapter-value" type="s3m:mc-cjn622weg000jlw8pszv5qhos"/>
#   <xs:complexType name="mc-cjn622weg000jlw8pszv5qhos">
#     <xs:annotation>
#       <xs:documentation>
#         Record the number of years of experience of the employee.
#         Definition: https%3A//datainsights.tech/examples/Experience%23Years
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn622weg000jlw8pszv5qhos">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdCountType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/Experience%23Years"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdCountType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Years of Experience"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='magnitude-status' type='s3m:MagnitudeStatus'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='error'  type='xs:int' default='0'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='accuracy' type='xs:int' default='0'/>
#           <xs:element maxOccurs='1' minOccurs='0'  name='xdcount-value'>
#             <xs:simpleType>
#             <xs:restriction base='xs:int'>
#               <xs:minInclusive value='0'/>
#               <xs:maxInclusive value='99'/>
#             </xs:restriction>
#             </xs:simpleType>
#           </xs:element>
#           <xs:element maxOccurs='1' minOccurs='1' name='xdcount-units' type='s3m:mc-cjn622wef000hlw8pscim9kee'/>
#           </xs:sequence>
#         </xs:restriction>
#       </xs:complexContent>
#     </xs:complexType>
#
#   <xs:element name="ms-cjn622wef000hlw8pscim9kee" type="s3m:mc-cjn622wef000hlw8pscim9kee"/>
#   <xs:complexType name="mc-cjn622wef000hlw8pscim9kee">
#     <xs:annotation>
#       <xs:documentation>
#         Count of the years of experience.
#         Definition: https%3A//datainsights.tech/examples/Experience
#       </xs:documentation>
#       <xs:appinfo>
#         <rdfs:Class rdf:about="mc-cjn622wef000hlw8pscim9kee">
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model_3_1_0.xsd#XdStringType"/>
#           <rdfs:subClassOf rdf:resource="https://www.s3model.com/ns/s3m/s3model/RMC"/>
#           <rdfs:isDefinedBy rdf:resource="https%3A//datainsights.tech/examples/Experience"/>
#         </rdfs:Class>
#       </xs:appinfo>
#     </xs:annotation>
#     <xs:complexContent>
#       <xs:restriction base="s3m:XdStringType">
#         <xs:sequence>
#           <xs:element maxOccurs="1" minOccurs="1" name="label" type="xs:string" fixed="Years"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="act" type="xs:string" default=""/>
#           <xs:element maxOccurs="1" minOccurs="0" ref="s3m:ExceptionalValue"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vtb" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="vte" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="tr" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="modified" type="xs:dateTime"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="latitude" type="xs:decimal"/>
#           <xs:element maxOccurs="1" minOccurs="0" name="longitude" type="xs:decimal"/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-value' type='xs:string'/>
#           <xs:element maxOccurs='1' minOccurs='0' name='xdstring-language' type='xs:language' default=''/>
#         </xs:sequence>
#       </xs:restriction>
#     </xs:complexContent>
#   </xs:complexType>
